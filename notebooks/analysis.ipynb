# %% [markdown]
# # Open Project 2026 — Dynamic Tariff Optimization
#
# Reproducible notebook mirroring `main.py`. Run from project root.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

import config
from main import main

main()

# %% [markdown]
# ## View Results

# %%
import pandas as pd
from IPython.display import Image, display

metrics = pd.read_csv(ROOT / 'outputs/evaluation_metrics.csv')
display(metrics.T)

for fig in ['demand_metrics.png', 'tariff_timeline.png', 'monitoring_kpis.png', 'urbanev_util_heatmap.png']:
    p = ROOT / 'outputs/figures' / fig
    if p.exists():
        display(Image(filename=str(p)))
